# %%
import pandas as pd

# Cargar el dataset desde un archivo CSV
dataset = pd.read_csv('/Users/aliciacaminero/Downloads/vehiculos-de-segunda-mano-sample.csv')

# Ver las primeras filas del dataset
dataset
# Out:
#       vehicle_type     make       model  \
# 0              car     Opel   Crossland
# 1              car     Opel   Crossland
# 2              car     Opel   Crossland
# 3              car     Opel   Crossland
# 4              car     Opel   Crossland
# ...            ...      ...         ...
# 99995          car  Citroen  C4 Picasso
# 99996          car  Citroen  C4 Picasso
# 99997          car  Citroen  C4 Picasso
# 99998          car  Citroen  C4 Picasso
# 99999          car  Citroen  C4 Picasso
#
#                                         version      fuel  year       kms  \
# 0                    1.2 GAS 110 GS Line 5p S/S  Gasolina  2022       5.0
# 1                      1.2 81kW (110CV) GS Line  Gasolina  2022   24847.0
# 2      1.5D 88kW (120CV) Business Elegance Auto    Diésel  2021   41356.0
# 3                 GS-Line 1.2 GAS MT6 S/S 110cv  Gasolina  2022      11.0
# 4                 GS-Line 1.2 GAS MT6 S/S 110cv  Gasolina  2022      11.0
# ...

# %%
unique_counts = dataset.nunique()
unique_counts
# Out:
# vehicle_type                 1
# make                        66
# model                      748
# version                   8658
# fuel                         4
# year                        43
# kms                       6643
# power                      349
# doors                        0
# shift                        2
# color                        0
# photos                      10
# description               6439
# price                     2665
# currency                     1
# location                   669
# publish_date               424
# update_date                 38
# dealer_name               1678
# dealer_description        1181
# dealer_address            1675
# dealer_zip_code            872
# dealer_city                665
# dealer_country_code          1
# dealer_is_professional       1
# dealer_website             888
# dealer_registered_at      1177
# date                        13
# dtype: int64

# %%
# Columnas que podemos borrar con = valores unicos doors y color

dataset.drop(columns=['doors', 'color'], inplace=True)

# Tambien podemos borrar la columna currency ya que su unico valor es el euro, dealer_country_code -> codigo de pais anunciante siempre es ES
# dealer_is_professional: Determina si el anunciante es o no profesional -> siempre es True

dataset.drop(columns=['currency', 'dealer_country_code', 'dealer_is_professional'], inplace=True)

# Borramos descripcion y photos

dataset.drop(columns=['photos', 'dealer_description', 'description', 'location', 'dealer_registered_at', 'vehicle_type'], inplace=True)

# %%
dataset
# Out:
#           make       model                                   version  \
# 0         Opel   Crossland                1.2 GAS 110 GS Line 5p S/S
# 1         Opel   Crossland                  1.2 81kW (110CV) GS Line
# 2         Opel   Crossland  1.5D 88kW (120CV) Business Elegance Auto
# 3         Opel   Crossland             GS-Line 1.2 GAS MT6 S/S 110cv
# 4         Opel   Crossland             GS-Line 1.2 GAS MT6 S/S 110cv
# ...        ...         ...                                       ...
# 99995  Citroen  C4 Picasso          BlueHDi 150 Feel 110 kW (150 CV)
# 99996  Citroen  C4 Picasso                                 Seduction
# 99997  Citroen  C4 Picasso                                 Seduction
# 99998  Citroen  C4 Picasso                                 Millenium
# 99999  Citroen  C4 Picasso                                 Millenium
#
#            fuel  year       kms  power      shift  price publish_date  \
# ...

# %%
dataset.info
# Out:
# <bound method DataFrame.info of           make       model                                   version  \
# 0         Opel   Crossland                1.2 GAS 110 GS Line 5p S/S
# 1         Opel   Crossland                  1.2 81kW (110CV) GS Line
# 2         Opel   Crossland  1.5D 88kW (120CV) Business Elegance Auto
# 3         Opel   Crossland             GS-Line 1.2 GAS MT6 S/S 110cv
# 4         Opel   Crossland             GS-Line 1.2 GAS MT6 S/S 110cv
# ...        ...         ...                                       ...
# 99995  Citroen  C4 Picasso          BlueHDi 150 Feel 110 kW (150 CV)
# 99996  Citroen  C4 Picasso                                 Seduction
# 99997  Citroen  C4 Picasso                                 Seduction
# 99998  Citroen  C4 Picasso                                 Millenium
# 99999  Citroen  C4 Picasso                                 Millenium
#
#            fuel  year       kms  power      shift  price publish_date  \
# ...

# %%
unique_cities = dataset['dealer_city'].unique()

unique_cities
# Out:
# array(['Pineda de Mar', 'Coslada', 'Madrid', 'Sabadell',
#        'Mollet del Vallès', 'Málaga', 'Móstoles', 'Badalona',
#        'Sant Boi de Llobregat', 'Almería', 'Vigo', 'Salamanca',
#        'Valencia', 'Cáceres', 'Barcelona', 'Camarma de Esteruelas',
#        'Colonia Pablo Iglesias', 'Villaviciosa de Odón', 'Girona',
#        'Bilbao', 'Sevilla', 'Orbazai', 'A Coruña', 'Torrefarrera',
#        'Olèrdola', 'Santa Maria del Aguila', 'Sant Vicenç de Montalt',
#        'Santiago de Compostela', 'Mercado Parque Corredor del Henares',
#        'Badajoz', 'Ciudad Real', 'Saladar',
#        'Castello/Castellon de La Plana', 'Hidraulica Santillana',
#        'Alicante/Alacant', 'Mercabilbao', 'Alameda del Obispo',
#        'Alcobendas', 'Zaragoza', 'Granollers', 'Estepona', 'Valdepeñas',
#        'Alzira', 'Las Rozas de Madrid', 'Murcia', 'Santander',
#        'Alcalá de Henares', 'Urbanitzacio El Medol', 'Granada',
#        'Donostia-San Sebastián', 'Toledo', 'Sant Cugat del Vallès',
# ...

# %%
# Mapeo de las ciudades a provincias
city_to_province_mapping = {
    'Madrid': 'Madrid',
    'Coslada': 'Madrid',
    'Sabadell': 'Barcelona',
    'Mollet del Vallès': 'Barcelona',
    'Málaga': 'Málaga',
    'Móstoles': 'Madrid',
    'Badalona': 'Barcelona',
    'Sant Boi de Llobregat': 'Barcelona',
    'Almería': 'Almería',
    'Vigo': 'Pontevedra',
    'Salamanca': 'Salamanca',
    'Valencia': 'Valencia',
    'Cáceres': 'Cáceres',
    'Barcelona': 'Barcelona',
    'Camarma de Esteruelas': 'Madrid',
    'Colonia Pablo Iglesias': 'Madrid',
    'Villaviciosa de Odón': 'Madrid',
    'Girona': 'Girona',
    'Bilbao': 'Bizkaia',
    'Sevilla': 'Sevilla',
    'Orbazai': 'A Coruña',
    'A Coruña': 'A Coruña',
    'Torrefarrera': 'Lleida',
    'Olèrdola': 'Barcelona',
    'Santa Maria del Aguila': 'Almería',
    'Sant Vicenç de Montalt': 'Barcelona',
    'Santiago de Compostela': 'A Coruña',
    'Badajoz': 'Badajoz',
    'Ciudad Real': 'Ciudad Real',
    'Alzira': 'Valencia',
    'Las Rozas de Madrid': 'Madrid',
    'Murcia': 'Murcia',
    'Santander': 'Cantabria',
    'Alcalá de Henares': 'Madrid',
    'Granada': 'Granada',
    'Donostia-San Sebastián': 'Gipuzkoa',
    'Toledo': 'Toledo',
    'Sant Cugat del Vallès': 'Barcelona',
    'Valladolid': 'Valladolid',
    'Bormujos': 'Sevilla',
    'Alcañiz': 'Teruel',
    'Alcorcón': 'Madrid',
    'Albal': 'Valencia',
    'Santafe': 'Granada',
    'Collado Villalba': 'Madrid',
    'Getafe': 'Madrid',
    'Torremolinos': 'Málaga',
    'Paterna': 'Valencia',
    'Pamplona/Iruña': 'Navarra',
    'Fuenlabrada': 'Madrid',
    'Sant Antoni de Vilamajor': 'Barcelona',
    'Tarrega': 'Lleida',
    'Antequera': 'Málaga',
    'Algete': 'Madrid',
    'Torrejón de Ardoz': 'Madrid',
    'San Fernando de Henares': 'Madrid',
    'Puerto de Sagunto': 'Valencia',
    'Alcover': 'Tarragona',
    'Vitoria-Gasteiz': 'Álava',
    'Catarroja': 'Valencia',
    'Palamós': 'Girona',
    'Albacete': 'Albacete',
    'Cádiz': 'Cádiz',
    'Leganés': 'Madrid',
    'Mairena del Aljarafe': 'Sevilla',
    'Montilla': 'Córdoba',
    'Huelva': 'Huelva',
    'Parets del Vallès': 'Barcelona',
    'Castellón de la Plana': 'Castellón',
    'Elche': 'Alicante',
    'Palma de Mallorca': 'Islas Baleares',
    'Tarragona': 'Tarragona',
    'Reus': 'Tarragona',
    'Ourense': 'Ourense',
    'Igualada': 'Barcelona',
    'Lleida': 'Lleida',
    'Burgos': 'Burgos',
    'Manresa': 'Barcelona',
    'León': 'León',
    'Jaén': 'Jaén',
    'Sant Quirze del Vallès': 'Barcelona',
    'Santiago de Compostela': 'A Coruña',
    'Salamanca': 'Salamanca',
    'Algeciras': 'Cádiz',
    'Marbella': 'Málaga',
    'Parla': 'Madrid',
    'Lepe': 'Huelva',
    'Vélez-Málaga': 'Málaga',
    'Almería': 'Almería',
    'Benidorm': 'Alicante',
    'Gandía': 'Valencia',
    'Reus': 'Tarragona',
    'Zaragoza': 'Zaragoza',
    'Don Benito': 'Badajoz',
    'Huesca': 'Huesca',
    'Torrevieja': 'Alicante',
    'Orihuela': 'Alicante',
    'Vitoria-Gasteiz': 'Álava',
    'Pineda de Mar': 'Barcelona',
    'Mercado Parque Corredor del Henares': 'Madrid',
    'Saladar': 'Valencia',
    'Castello/Castellon de La Plana': 'Castellón',
    'Granollers': 'Barcelona',
    'Estepona': 'Málaga',
    'Hidraulica Santillana': 'Cantabria',
    'Alicante/Alacant': 'Alicante',
    'Mercabilbao': 'Vizcaya',
    'Alameda del Obispo': 'Madrid',
    'Alcobendas': 'Madrid',
    'Atarrabia': 'Navarra',
    'Valdepeñas': 'Ciudad Real',
    'Urbanitzacio El Medol': 'Tarragona',
    'Palau-Solita I Plegamans': 'Barcelona',
    'Alcalá de Guadaíra': 'Sevilla',
    'Espinardo': 'Murcia',
    'Fortiñon': 'Álava',
    'Pontevedra': 'Pontevedra',
    'Molino de La Hoz': 'Madrid',
    'Torredonjimeno': 'Jaén',
    'Barrio Peral': 'Murcia',
    'Novelda': 'Alicante',
    'Club Encinas': 'Madrid',
    'Kukullaga': 'Vizcaya',
    'Castellón': 'Castellón',
    'Elx/Elche': 'Alicante',
    'Aspe': 'Alicante',
    'Bacarot': 'Castellón',
    'Santimami': 'Girona',
    'Olot': 'Girona',
    'Sant Vicent del Raspeig': 'Alicante',
    'Santa Perpètua de Mogoda': 'Barcelona',
    'San Martin': 'Álava',
    'El Aeroport del Prat': 'Barcelona',
    'La Borbolla': 'Alicante',
    'Villena': 'Alicante',
    'Òrrius': 'Barcelona',
    'Ullastrell': 'Barcelona',
    'Urbanizacion La Granjilla': 'Madrid',
    'Arroyo de La Miel': 'Málaga',
    'Gavarres': 'Girona',
    'Rafelbuñol/Rafelbunyol': 'Valencia',
    'Sant Feliu de Llobregat': 'Barcelona',
    'Vilafranca del Penedès': 'Barcelona',
    'Arriaga': 'Bizkaia',
    'Sant Fruitós de Bages': 'Barcelona',
    'Sedaví': 'Valencia',
    'El Villar': 'Valencia',
    'Palafrugell': 'Girona',
    'Lebrija': 'Sevilla',
    'Amposta': 'Tarragona',
    'Arroyomolinos': 'Madrid',
    'Fornells de la Selva': 'Girona',
    'Carretera de Cobeña': 'Madrid',
    'Cornella de Llobregat': 'Barcelona',
    'Gijón': 'Asturias',
    'Poligono Industrial San Fernando': 'Cádiz',
    'Tortosa': 'Tarragona',
    'Las Navas del Marqués': 'Ávila',
    'Úbeda': 'Jaén',
    'Terrassa': 'Barcelona',
    'Perillo': 'A Coruña',
    'Lliça de Vall': 'Barcelona',
    'Coiros de Arriba': 'A Coruña',
    'Linares': 'Jaén',
    'Calonge': 'Girona',
    'Daganzo de Arriba': 'Madrid',
    'Sant Vicenç dels Horts': 'Barcelona',
    'Montcada i Reixac': 'Barcelona',
    'Beade': 'Vigo',
    'Campamento': 'Madrid',
    'San Bizenti-Barakaldo': 'Bizkaia',
    'Baza': 'Granada',
    'Viladecans': 'Barcelona',
    'Agirre-Aperribai': 'Bizkaia',
    'Bonavista': 'Tarragona',
    'El Cigarral': 'Toledo',
    'Camping Costa Blanca': 'Alicante',
    'Puerto Lumbreras': 'Murcia',
    'Cieza': 'Murcia',
    'Los Negrales': 'Madrid',
    'Cardedeu': 'Barcelona',
    'Canals': 'Valencia',
    'Esplugues de Llobregat': 'Barcelona',
    'Poligono Industrial Aimayr': 'Ávila',
    'Oviedo': 'Asturias',
    'Alcorisa': 'Teruel',
    'Rivas Vaciamadrid': 'Madrid',
    'Albatera': 'Alicante',
    'Gelves': 'Sevilla',
    'Silla': 'Valencia',
    'Majadahonda': 'Madrid',
    'Villanueva del Arzobispo': 'Jaén',
    'La Poveda': 'Madrid',
    'Begíjar': 'Jaén',
    'Poligono Da Louzaneta': 'Alicante',
    'Elgoibar': 'Gipuzkoa',
    'Trapaga-Causo': 'Bizkaia',
    'Dos Hermanas': 'Sevilla',
    'Lucena': 'Córdoba',
    'Vilanova i la Geltrú': 'Barcelona',
    "L'Hospitalet de Llobregat": 'Barcelona',
    'El Campello': 'Alicante',
    'Balmaseda': 'Bizkaia',
    'Gavà': 'Barcelona',
    'El Prat de Llobregat': 'Barcelona',
    'Yecla': 'Murcia',
    'Molins de Rei': 'Barcelona',
    'Torrejón de Velasco': 'Madrid',
    'Fuengirola': 'Málaga',
    'Utebo': 'Zaragoza',
    'Benimamet': 'Valencia',
    'Tordera': 'Barcelona',
    'San Jose de La Rinconada': 'Sevilla',
    'Leioa': 'Bizkaia',
    'Artajona': 'Navarra',
    'Villanueva del Arzobispo': 'Jaén',
    'La Poveda': 'Madrid',
    'Begíjar': 'Jaén',
    'Poligono Da Louzaneta': 'Alicante',
    'Elgoibar': 'Gipuzkoa',
    'Silla': 'Valencia',
    'Trapaga-Causo': 'Bizkaia',
    'Dos Hermanas': 'Sevilla',
    'Lucena': 'Córdoba',
    'Vilanova i la Geltrú': 'Barcelona',
    'L\'Hospitalet de Llobregat': 'Barcelona',
    'El Campello': 'Alicante',
    'Balmaseda': 'Bizkaia',
    'Gavà': 'Barcelona',
    'El Prat de Llobregat': 'Barcelona',
    'Yecla': 'Murcia',
    'Molins de Rei': 'Barcelona',
    'Torrejón de Velasco': 'Madrid',
    'Fuengirola': 'Málaga',
    'Utebo': 'Zaragoza',
    'Benimamet': 'Valencia',
    'Tordera': 'Barcelona',
    'San Jose de La Rinconada': 'Sevilla',
    'Leioa': 'Bizkaia',
    'Las Matas': 'Madrid',
    'Alcaudete': 'Jaén',
    'Roquetas de Mar': 'Almería',
    'Revilla de Camargo': 'Cantabria',
    'La Roca del Vallès': 'Barcelona',
    'San Juan Mozarrifar': 'Zaragoza',
    'Guarnizo': 'Cantabria',
    'Llerona': 'Barcelona',
    'Constantí': 'Tarragona',
    'Mataró': 'Barcelona',
    'Las Parcelas': 'Valencia',
    'Poligono Fuente del Jarro': 'Valencia',
    'Manacor': 'Baleares',
    'Santa Coloma de Gramenet': 'Barcelona',
    'Laguna de Duero': 'Valladolid',
    'Doña Manuela': 'Badajoz',
    'Cocentaina': 'Alicante',
    'Aldaia': 'Valencia',
    'Barbera del Valles': 'Barcelona',
    'Caravaca de la Cruz': 'Murcia',
    'Rubí': 'Barcelona',
    'Añorga': 'Gipuzkoa',
    'Mérida': 'Badajoz',
    'San Sebastián de Los Reyes': 'Madrid',
    'Ontinyent': 'Valencia',
    'El Puerto de Santa María': 'Cádiz',
    'Playa Lisa': 'Alicante',
    'Caldes de Montbui': 'Barcelona',
    'Gamonal': 'Burgos',
    'Poligono Industrial a Gandara': 'Pontevedra',
    'Carretera de San Martin de La Vega': 'Madrid',
    'Alhaurín el Grande': 'Málaga',
    'Robledo de Chavela': 'Madrid',
    'Lorca': 'Murcia',
    'Humanes de Madrid': 'Madrid',
    'Acea de Ama': 'Toledo',
    'Sant Joanet': 'Valencia',
    'El Verger': 'Alicante',
    'Torredembarra': 'Tarragona',
    'Almagro': 'Ciudad Real',
    'Elda': 'Alicante',
    'Redován': 'Alicante',
    'Lugo': 'Lugo',
    'Barbastro': 'Huesca',
    'Rota': 'Cádiz',
    'Pozuelo de Alarcón': 'Madrid',
    'Ávila': 'Ávila',
    'El Moli d\'en Rovira': 'Barcelona',
    'Rutis': 'A Coruña',
    'Monteagudo': 'Murcia',
    'La Serna': 'Ciudad Real',
    'Daimiel': 'Ciudad Real',
    'Valdemoro': 'Madrid',
    'Vinaros': 'Castellón',
    'Castellciutat': 'Lleida',
    'Vilamalla': 'Girona',
    'Torrellano': 'Alicante',
    'Valdefuentes': 'Badajoz',
    'Olivenza': 'Badajoz',
    'Churriana': 'Málaga',
    'Ugarte': 'Álava',
    'Córdoba': 'Córdoba',
    'Sant Adrià de Besòs': 'Barcelona',
    'Vilches': 'Jaén',
    'Nava': 'Asturias',
    'Andújar': 'Jaén',
    'Crevillent': 'Alicante',
    'Bolaños de Calatrava': 'Ciudad Real',
    'Fuente el Saz de Jarama': 'Madrid',
    'Llano de Brujas': 'Murcia',
    'Gamarra Menor': 'Álava',
    'Granda': 'Asturias',
    'Mungia': 'Vizcaya',
    'Camino Viejo de Callosa': 'Alicante',
    'Castellón de la Plana/Castelló de la Plana': 'Castellón',
    'Barrio de Porta': 'Barcelona',
    'Burjassot': 'Valencia',
    'La Puebla de Alfindén': 'Zaragoza',
    'Durango': 'Vizcaya',
    'Xativa': 'Valencia',
    'Blanes': 'Girona',
    'O Birloque': 'A Coruña',
    'Bertamirans': 'A Coruña',
    'La Calavera': 'Ciudad Real',
    'Illescas': 'Toledo',
    'Vila-Real/Villarreal': 'Castellón',
    'Valverde de Leganés': 'Badajoz',
    'Bigastro': 'Alicante',
    'Palafolls': 'Barcelona',
    'Partida Altabix': 'Alicante',
    'Casas Novas': 'A Coruña',
    'Rosselló': 'Lleida',
    'Vic': 'Barcelona',
    'Bonrepos I Mirambell': 'Valencia',
    'Vilanoveta': 'Valencia',
    'El Tosalet': 'Alicante',
    'El Esparragal': 'Murcia',
    'Viator': 'Almería',
    'Cúllar Vega': 'Granada',
    'La Pobla de Vallbona': 'Valencia',
    'Benetússer': 'Valencia',
    'Oseiro': 'A Coruña', 
    'Lliça d\'Amunt': 'Barcelona',
    'Armentia': 'Álava',
    'Nueva Andalucia': 'Málaga',
    'Artatza': 'Vizcaya',
    'O Rio Da Ucha': 'Pontevedra',
    'Cambrils': 'Tarragona',
    'El Parador': 'Almería',
    'Massanassa': 'Valencia',
    'Arganda del Rey': 'Madrid',
    'Figueres': 'Girona',
    'Mesas de Santa Rosa': 'Castellón',
    'Vilatenim': 'Girona',
    'Navalcarnero': 'Madrid',
    'Utrera': 'Sevilla',
    'Valls': 'Tarragona',
    'Olías del Rey': 'Toledo',
    'Pinto': 'Madrid',
    'Quart de Poblet': 'Valencia',
    'Binéfar': 'Huesca',
    'Riba-Roja de Turia': 'Valencia',
    'Vilagarcía de Arousa': 'Pontevedra',
    'Orkoien': 'Navarra',
    'Paiporta': 'Valencia',
    'Las Vegas': 'Madrid',
    'Piera': 'Barcelona',
    'Silleda': 'Pontevedra',
    'Logroño': 'La Rioja',
    'La / Nucia-Hill Nucia Hills': 'Alicante',
    'Cabrera de Mar': 'Barcelona',
    'Sant Joan Despí': 'Barcelona',
    'Arizgoiti': 'Vizcaya',
    'Irun': 'Guipúzcoa',
    'Talayuela': 'Cáceres',
    'Aldeaseca de La Armuña': 'Salamanca',
    'Lugar Nuevo de La Corona': 'Ciudad Real',
    'Monteprincipe': 'Madrid',
    'Arbuio': 'Álava',
    'Quintanar de la Orden': 'Toledo',
    'Bollullos de la Mitación': 'Sevilla',
    'Coria del Río': 'Sevilla',
    'Plasencia': 'Cáceres',
    'Baena': 'Córdoba',
    'Montijo': 'Badajoz',
    'Castelldefels': 'Barcelona',
    'Alcantarilla': 'Murcia',
    'Guadalajara': 'Guadalajara',
    'El Mas Oliva': 'Alicante',
    'Petrer': 'Alicante',
    'Mijas': 'Málaga',
    'Benicarló': 'Castellón',
    'Puçol': 'Valencia',
    'Armilla': 'Granada',
    'Sondika': 'Vizcaya',
    'Cubas de la Sagra': 'Madrid',
    'Errenteria': 'Guipúzcoa',
    'Herrera del Duque': 'Badajoz',
    'Sant Antoni de Calonge': 'Girona',
    'Deiro': 'A Coruña',
    'Segovia': 'Segovia',
    'Mejorada del Campo': 'Madrid',
    'Aranjuez': 'Madrid',
    'Los Garres': 'Murcia',
    'Puente Tocinos': 'Murcia',
    'Santa Cruz Santa Cruz': 'Badajoz',
    'Prado': 'Madrid',
    'Puebla de la Calzada': 'Badajoz',
    'Palencia': 'Palencia',
    'La Zubia': 'Granada',
    'Ripollet': 'Barcelona',
    'La Garriga': 'Barcelona',
    'El Villar de Arnedo': 'La Rioja',
    'Los Antolinos': 'Cuenca',
    'Los Yébenes': 'Toledo',
    'Santiago y Zaraiche': 'Murcia',
    'Foios': 'Valencia',
    'Cogullada': 'Zaragoza',
    'Poligono Industrial Madanela': 'Zaragoza',
    'Oliva': 'Valencia',
    'Bailén': 'Jaén',
    'Laraxe': 'A Coruña',
    'San Luis de Sabinillas': 'Málaga',
    'Conil de la Frontera': 'Cádiz',
    'La Canonja': 'Tarragona',
    'Malgrat de mar': 'Barcelona',
    'Berga': 'Barcelona',
    'Boimorto': 'A Coruña',
    'Fuente del Rey': 'Ciudad Real',
    'Santurtzi': 'Vizcaya',
    'Rubians': 'Lleida',
    'Igollo de Camargo': 'Cantabria',
    'Albox': 'Almería',
    'Los Montesinos': 'Alicante',
    'Carbajosa de la Sagrada': 'Salamanca',
    'La Puebla del Río': 'Sevilla',
    'Les Borges Blanques': 'Lleida',
    'Granja de Rocamora': 'Alicante',
    'Alella': 'Barcelona',
    'Deltebre': 'Tarragona',
    'Carcaixent': 'Valencia',
    'Villares de la Reina': 'Salamanca',
    'Camargo': 'Cantabria',
    'Sotillo de la Adrada': 'Ávila',
    'Torrent': 'Valencia',
    'Lorquí': 'Murcia',
    'Monserrat': 'Valencia',
    'Las Norias de Daza': 'Almería',
    'Orilla del Azarbe': 'Murcia',
    'Celra': 'Girona',
    'Poligono Industrial Parque Industrial de Elche': 'Alicante',
    'Campillos': 'Málaga',
    'Quintanar del Rey': 'Cuenca',
    'Zaratamo': 'Bizkaia',
    'Cerceda': 'A Coruña',
    'Buenas Noches': 'Cádiz',
    'Paracuellos de Jarama': 'Madrid',
    'R.a.c.e.': 'Madrid',
    'La Estacada': 'Toledo',
    'Cunit': 'Tarragona',
    'Prado del Rey': 'Cádiz',
    'Verín': 'Ourense',
    'Argamasilla de Calatrava': 'Ciudad Real',
    'Casillas': 'Toledo',
    'San Fernando de Henares Madrid': 'Madrid',
    'Coria': 'Badajoz',
    'Mairena del Alcor': 'Sevilla',
    'Almonte': 'Huelva',
    'Los Palacios y Villafranca': 'Sevilla',
    'Las Chafiras': 'Santa Cruz de Tenerife',
    'Alfafar': 'Valencia',
    'Varea': 'La Rioja',
    'Alhendín': 'Granada',
    'Puente Botero': 'Córdoba',
    'Aizoain': 'Navarra',
    'Santa Pola': 'Alicante',
    'Montmeló': 'Barcelona',
    'Muxa': 'Badajoz',
    'O Porriño': 'Pontevedra',
    'San Benito': 'Badajoz',
    'Molina de Segura': 'Murcia',
    'Residencia Nuestra Señora del Pilar': 'Zaragoza',
    'O Graxal': 'A Coruña',
    'Churriana de la Vega': 'Granada',
    'Benisanó': 'Valencia',
    'El Calvario': 'Asturias',
    'Ibiricu de Egües': 'Navarra',
    'Beniel': 'Murcia',
    'Torres de la Alameda': 'Madrid',
    'Canovelles': 'Barcelona',
    'Cornella del Terri': 'Girona',
    'Aljucer': 'Murcia',
    'Trasona': 'Asturias',
    'Pilas': 'Sevilla',
    'Vilalba': 'Lugo',
    'Urbi': 'Alicante',
    'Sant Feliu de Codines': 'Barcelona',
    'Sant Celoni': 'Barcelona',
    'Tabernas': 'Almería',
    'Residencial Can Carner': 'Barcelona',
    'Tudela': 'Navarra',
    'Ajalvir': 'Madrid',
    'Guadassuar': 'Valencia',
    'Móra d\'Ebre': 'Tarragona',
    'Casarrubuelos': 'Madrid',
    'Caspe': 'Zaragoza',
    'Chiclana de la Frontera': 'Cádiz',
    'Cañada Hermosa': 'Murcia',
    'Montequinto': 'Sevilla',
    'Martiartu': 'Vizcaya',
    'La Papiola': 'Barcelona',
    'La Esperanza': 'Santa Cruz de Tenerife',
    'Inca': 'Baleares',
    'Salt': 'Girona',
    'Alaquas': 'Valencia',
    'Peligros': 'Granada',
    'Baeza': 'Jaén',
    'Añover de Tajo': 'Toledo',
    'Urbanizacion Beltraneja': 'Madrid',
    'Velilla de San Antonio': 'Madrid',
    'Tajonar/Taxoare': 'Navarra',
    'Iniesta': 'Cuenca',
    'Los Combos': 'Segovia',
    'Las Pajanosas': 'Sevilla',
    'Lora del Río': 'Sevilla',
    'Manises': 'Valencia',
    'Motril': 'Granada',
    'Aldea Nova': 'Segovia',
    'Torrelodones': 'Madrid',
    'Mira-Sol': 'Barcelona',
    'Ibi': 'Alicante',
    'Mollerussa': 'Lleida',
    'La Escucha': 'Teruel',
    'Martorell': 'Barcelona',
    'Bétera': 'Valencia',
    'Picanya': 'Valencia',
    'Iznatoraf': 'Jaén',
    'Los Tanagos': 'Madrid',
    'Campo Real': 'Madrid',
    'Caudete': 'Albacete',
    'La Sénia': 'Tarragona',
    'Zaratán': 'Valladolid',
    "Torrijos": "Toledo",
    "Poligono Tres Caminos": "Toledo",
    "Jerez de la Frontera": "Cádiz",
    "Irún": "Guipúzcoa",
    "Collado Mediano": "Madrid",
    "Beniparrell": "Valencia",
    "Alqueria": "Valencia",
    "Sueca": "Valencia",
    "Montblanc": "Tarragona",
    "Zamora": "Zamora",
    "Cuenca": "Cuenca",
    "Urduliz": "Bizkaia",
    "Lugones": "Asturias",
    "Ventas del Carrizal": "Madrid",
    "Guardamar del Segura": "Alicante",
    "Manzanares": "Ciudad Real",
    "Ciudad Deportiva del Jarama": "Madrid",
    "Casserres": "Barcelona",
    "Vega Santa Maria": "Madrid",
    "Medina del Campo": "Valladolid",
    "Urbanizacion Calipo": "Madrid",
    "Parque Empresarial La Moraleja": "Madrid",
    "Moraleja de Enmedio": "Madrid",
    "Alcázar de San Juan": "Ciudad Real",
    "Mula": "Murcia",
    "Camas": "Sevilla",
    "La Font": "Castellón",
    "Martos": "Jaén",
    "Cerdanyola del Vallès": "Barcelona",
    "Casas de Don Gómez": "Badajoz",
    "Vullpellac": "Girona",
    "El Saucejo": "Sevilla",
    "Maliaño": "Cantabria",
    "Cordovilla": "Navarra",
    "Ulldecona": "Tarragona",
    "Ferrol": "A Coruña",
    "Sant Carles de La Rapita": "Tarragona",
    "Pedralba": "Valencia",
    "Sax": "Alicante",
    "Algars": "Tarragona",
    "Sant Just Desvern": "Barcelona",
    "Ondara": "Alicante",
    "Manlleu": "Barcelona",
    "Montgat": "Barcelona",
    "Almargen": "Málaga",
    "Gamarra Mayor": "Álava",
    "Catral": "Alicante",
    "Ocaña": "Toledo",
    "Guardiola de Berguedà": "Barcelona",
    "El Papiolet": "Barcelona",
    "Bekea": "Álava",
    "La Venta del Viso": "Ciudad Real",
    "La Seu d'Urgell": "Lleida",
    "La Pobla de Mafumet": "Tarragona",
    "Cuéllar": "Segovia",
    "Arragua": "Guipúzcoa",
    "Llocnou de Sant Jeroni": "Valencia",
    "Sant Joan les Fonts": "Girona",
    "Barrio del Progreso": "Murcia",
    "Churra Cabezo de Torres": "Murcia",
    "Poligono Los Villares Reina": "Jaén",
    "Plataforma Logistica Plaza": "Zaragoza",
    "Golmés": "Lleida",
    "Atarfe": "Granada",
    "Santa Cruz de Bezana": "Cantabria",
    "Mosteiron": "Pontevedra",
    "Polinya": "Barcelona",
    "Camporredondo": "Cantabria",
    "La Llagosta": "Barcelona",
    "El Peñón": "Guadalajara",
    "Colonia Rocafiguera": "Barcelona",
    "La Solana": "Ciudad Real",
    "Alboraya": "Valencia",
    "L' Alcudia de Crespins": "Valencia",
    "Tercia": "Murcia",
    "L' Olleria": "Valencia",
    "Griñón": "Madrid",
    "Vilobí d'Onyar": "Girona",
    "Bigues": "Barcelona",
    "Sant Feliu de Guíxols": "Girona",
    "Padul": "Granada",
    "Albolote": "Granada",
    "Gallecs": "Barcelona",
    "El Cuervo": "Sevilla",
    "Partida Los Pinos": "Alicante",
    "Xirivella": "Valencia",
    "Velilla-Taramay": "Granada",
    "La Cruz": "Las Palmas",
    "Alberic": "Valencia",
    "Poligono Industrial Ajalvir": "Madrid",
    "O Barco": "Ourense",
    "Armunia": "León",
    "Carretera Castro de Elviña": "A Coruña",
    "Armunia": "León",
    "Carretera del Km. 17,500 Al 22,600 Madrid-Colmenar Viejo": "Madrid",
    "La Felguera": "Asturias",
    "Moguer": "Huelva",
    "Bencarron": "Valladolid",
    "Torrelavega": "Cantabria",
    "Sunbilla": "Navarra",
    "Valdecuenca": "Cuenca",
    "Arenys de Mar": "Barcelona",
    "Calahorra": "La Rioja",
    "Tora": "Barcelona",
    "Armunia": "León",
    "Sunbilla": "Navarra",
    "Pola de Siero": "Asturias",
    "Xabia/Javea": "Alicante",
    "Tavernes de la Valldigna": "Valencia",
    "Tarazona": "Zaragoza",
    "Palmera": "Valencia",
    "Sant Pau de Segúries": "Girona",
    "Santa Rosa": "La Rioja",
    "Museros": "Valencia",
    "Villanueva de la Serena": "Badajoz",
    "Carrión de los Céspedes": "Sevilla",
    "Sangonera La Seca": "Murcia",
    "Urbanizacion Las Bizarricas": "Murcia",
    "Pla de na Tesa": "Islas Baleares",
    "Tamaraceite": "Las Palmas",
    "Llinars del Vallès": "Barcelona",
    "Urbanitzacio Can Valls-To": "Barcelona",
    "L'/Alqueria de La Condesa Alqueria de La Comtessa": "Valencia",
    "Ripoll": "Girona",
    "El Raval de La Llet": "Valencia",
    "Tavernes Blanques": "Valencia",
    "Aeropuerto de Noain": "Navarra",
    "Sant Andreu de la Barca": "Barcelona",
    "Morales del Vino": "Zamora",
    "Cadrete": "Zaragoza",
    "Sagunt/Sagunto": "Valencia",
    "Almassera": "Valencia",
    "Sant Quirze de Besora": "Barcelona",
    "San Clemente": "Cuenca",
    "Lloret de Mar": "Girona",
    "Emisora Radio Elect Campillo": "Navarra",
    "El Caleyu": "Asturias",
    "Talavera de la Reina": "Toledo",
    "Balsareny": "Barcelona",
    "Foz": "Lugo",
    "L' Escala": "Girona",
    "Parga": "Lugo",
    "Petra": "Baleares",
    "A Cruz": "La Coruña",
    "Orio": "Guipúzcoa",
    "Urbanizacion Las Colinas": "Alicante",
    "Jerez de los Caballeros": "Badajoz",
    "La Puebla de Cazalla": "Sevilla",
    "Palma del Río": "Córdoba",
    "Teruel": "Teruel",
    "Olesa de Montserrat": "Barcelona",
    "Avilés": "Asturias",
    "Miguelturra": "Ciudad Real",
    "Portals Nous": "Islas Baleares",
    "San Antonio de Benagéber": "Valencia",
    "Montagut": "Girona",
    "Nonduermas": "Murcia",
    "La Hornera": "Asturias",
}

# %%
# Asignar las provincias a las ciudades
dataset['province'] = dataset['dealer_city'].map(city_to_province_mapping)

# Verificar los resultados
print(dataset[['dealer_city', 'province']].head())

# Opcional: Contar las ventas por provincia
sales_by_province = dataset.groupby('province').size().sort_values(ascending=False)
print(sales_by_province)
# Out:
#          dealer_city   province
# 0      Pineda de Mar  Barcelona
# 1            Coslada     Madrid
# 2             Madrid     Madrid
# 3           Sabadell  Barcelona
# 4  Mollet del Vallès  Barcelona
# province
# Madrid                    20352
# Barcelona                 15343
# Valencia                   8893
# Málaga                     6220
# Sevilla                    5344
# Alicante                   4124
# Murcia                     3878
# Pontevedra                 3858
# Almería                    3758
# Granada                    3186
# Ciudad Real                3180
# Bizkaia                    2759
# A Coruña                   2020
# Badajoz                    1920
# Castellón                  1495
# Zaragoza                   1433
# Navarra                    1212
# Cantabria                  1209
# Vizcaya                    1085
# Girona                     1056
# Tarragona                   950
# Albacete                    891
# Islas Baleares              669
# ...

# %%
dataset[['dealer_city', 'province']]
# Out:
#              dealer_city   province
# 0          Pineda de Mar  Barcelona
# 1                Coslada     Madrid
# 2                 Madrid     Madrid
# 3               Sabadell  Barcelona
# 4      Mollet del Vallès  Barcelona
# ...                  ...        ...
# 99995            Saladar   Valencia
# 99996           Valencia   Valencia
# 99997           Valencia   Valencia
# 99998           Valencia   Valencia
# 99999           Valencia   Valencia
#
# [100000 rows x 2 columns]

# %%
# Filtrar las filas donde 'province' es NaN y 'dealer_city' no es NaN
rows_with_nan_province_non_nan_city = dataset[dataset['province'].isna() & dataset['dealer_city'].notna()]

# Ver las primeras filas con provincias NaN y ciudades no NaN
rows_with_nan_province_non_nan_city[['dealer_city', 'province']].tail(30)
# Out:
# Empty DataFrame
# Columns: [dealer_city, province]
# Index: []

# %%
#dataset.to_csv('dataset_limpio.csv', index=False)
